# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seoul_df = pd.read_csv("seoul_df.csv")
seoul_info = pd.read_csv("seoul_info.csv")
world_corona = pd.read_csv("world_corona_201104.csv")

# %%
world_corona.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.498
# 1      AFG      Asia  ...           64.83                   0.498
# 2      AFG      Asia  ...           64.83                   0.498
# 3      AFG      Asia  ...           64.83                   0.498
# 4      AFG      Asia  ...           64.83                   0.498
#
# [5 rows x 49 columns]

# %% [markdown]
# 1. world_corona 데이터프레임에서 male_smokers 칼럼을 삭제하는 코드를 작성하시오(1점)

# %%
world_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53987 entries, 0 to 53986
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            53987 non-null  object
#  1   continent                           53987 non-null  object
#  2   location                            53987 non-null  object
#  3   date                                53987 non-null  object
#  4   total_cases                         50389 non-null  float64
#  5   new_cases                           53311 non-null  float64
#  6   new_cases_smoothed                  52516 non-null  float64
#  7   total_deaths                        41305 non-null  float64
#  8   new_deaths                          53311 non-null  float64
#  9   new_deaths_smoothed                 52516 non-null  float64
#  10  total_cases_per_million             50389 non-null  float64
# ...

# %%
world_corona.drop(columns = ['male_smokers'], inplace = True)

# %%
world_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53987 entries, 0 to 53986
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            53987 non-null  object
#  1   continent                           53987 non-null  object
#  2   location                            53987 non-null  object
#  3   date                                53987 non-null  object
#  4   total_cases                         50389 non-null  float64
#  5   new_cases                           53311 non-null  float64
#  6   new_cases_smoothed                  52516 non-null  float64
#  7   total_deaths                        41305 non-null  float64
#  8   new_deaths                          53311 non-null  float64
#  9   new_deaths_smoothed                 52516 non-null  float64
#  10  total_cases_per_million             50389 non-null  float64
# ...

# %% [markdown]
# 2. world_corona의 수치 칼럼에 대해 기술통계량을 한 번에 볼 수 있는 코드를 1줄로 작성하시오.(1점)

# %%
world_corona.describe()
# Out:
#         total_cases      new_cases  ...  life_expectancy  human_development_index
# count  5.038900e+04   53311.000000  ...     53291.000000             46889.000000
# mean   7.614745e+04     892.673838  ...        73.968434                 0.722903
# std    4.586467e+05    4998.455629  ...         7.413691                 0.153185
# min    1.000000e+00   -8261.000000  ...        53.280000                 0.354000
# 25%    1.520000e+02       0.000000  ...        69.870000                 0.601000
# 50%    1.903000e+03      13.000000  ...        75.400000                 0.752000
# 75%    1.876500e+04     205.000000  ...        79.380000                 0.847000
# max    9.383979e+06  101273.000000  ...        86.750000                 0.953000
#
# [8 rows x 43 columns]

# %% [markdown]
# 3. world_corona의 모든 칼럼명을 출력하여 볼 수 있는 코드를 작성하시오.(1점)

# %%
world_corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53987 entries, 0 to 53986
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            53987 non-null  object
#  1   continent                           53987 non-null  object
#  2   location                            53987 non-null  object
#  3   date                                53987 non-null  object
#  4   total_cases                         50389 non-null  float64
#  5   new_cases                           53311 non-null  float64
#  6   new_cases_smoothed                  52516 non-null  float64
#  7   total_deaths                        41305 non-null  float64
#  8   new_deaths                          53311 non-null  float64
#  9   new_deaths_smoothed                 52516 non-null  float64
#  10  total_cases_per_million             50389 non-null  float64
# ...

# %% [markdown]
# 4. world_corona 데이터프레임에 'is_valid'라는 칼럼을 추가하되, 'is_valid' 칼럼의 기본값은 1으로 설정하시오(2점)

# %%
world_corona['is_valid'] = 1

# %%
world_corona.head()
# Out:
#   iso_code continent  ... human_development_index is_valid
# 0      AFG      Asia  ...                   0.498        1
# 1      AFG      Asia  ...                   0.498        1
# 2      AFG      Asia  ...                   0.498        1
# 3      AFG      Asia  ...                   0.498        1
# 4      AFG      Asia  ...                   0.498        1
#
# [5 rows x 49 columns]

# %% [markdown]
# 5.world_corona 데이터에서 location이 'France'인 데이터만 추출하는 코드를 작성하시오(2점)

# %%
world_corona[world_corona['location'] == 'France']
# Out:
#       iso_code continent  ... human_development_index is_valid
# 17478      FRA    Europe  ...                   0.901        1
# 17479      FRA    Europe  ...                   0.901        1
# 17480      FRA    Europe  ...                   0.901        1
# 17481      FRA    Europe  ...                   0.901        1
# 17482      FRA    Europe  ...                   0.901        1
# ...        ...       ...  ...                     ...      ...
# 17783      FRA    Europe  ...                   0.901        1
# 17784      FRA    Europe  ...                   0.901        1
# 17785      FRA    Europe  ...                   0.901        1
# 17786      FRA    Europe  ...                   0.901        1
# 17787      FRA    Europe  ...                   0.901        1
#
# [310 rows x 49 columns]

# %% [markdown]
# 6. seoul_df와 seoul_info를 seoul_df를 기준으로 병합(left join)하는 코드를 작성하시오(3점)

# %%
seoul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5748 entries, 0 to 5747
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      5748 non-null   int64
#  1   확진달     5748 non-null   int64
#  2   확진일     5748 non-null   int64
#  3   환자번호    5748 non-null   int64
#  4   국적      0 non-null      float64
#  5   환자정보    0 non-null      float64
#  6   지역      5748 non-null   object
#  7   여행력     458 non-null    object
#  8   접촉력     5748 non-null   object
#  9   조치사항    0 non-null      float64
#  10  상태      5357 non-null   object
#  11  이동경로    5520 non-null   object
#  12  등록일     5748 non-null   object
#  13  수정일     5748 non-null   object
#  14  노출여부    5748 non-null   object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 673.7+ KB

# %%
seoul_info.tail()
# Out:
#     순번  시군구코드 시군구명_한글          시군구명_영문  ESRI_PK         위도          경도
# 20  21  11470     양천구     Yangcheon-gu       22  37.527062  126.856153
# 21  22  11560    영등포구  Yeongdeungpo-gu       23  37.520641  126.913924
# 22  23  11620     관악구        Gwanak-gu       15  37.465399  126.943807
# 23  24  11200     성동구     Seongdong-gu       20  37.550675  127.040962
# 24  25  11170     용산구       Yongsan-gu       24  37.531101  126.981074

# %%
for col in list(seoul_info):
  seoul_df[col] = seoul_info[col]
seoul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5748 entries, 0 to 5747
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   연번       5748 non-null   int64
#  1   확진달      5748 non-null   int64
#  2   확진일      5748 non-null   int64
#  3   환자번호     5748 non-null   int64
#  4   국적       0 non-null      float64
#  5   환자정보     0 non-null      float64
#  6   지역       5748 non-null   object
#  7   여행력      458 non-null    object
#  8   접촉력      5748 non-null   object
#  9   조치사항     0 non-null      float64
#  10  상태       5357 non-null   object
#  11  이동경로     5520 non-null   object
#  12  등록일      5748 non-null   object
#  13  수정일      5748 non-null   object
#  14  노출여부     5748 non-null   object
#  15  순번       25 non-null     float64
#  16  시군구코드    25 non-null     float64
#  17  시군구명_한글  25 non-null     object
#  18  시군구명_영문  25 non-null     object
#  19  ESRI_PK  25 non-null     float64
# ...

# %% [markdown]
# 7. world_corona 데이터를 인구 순으로 내림차순 정렬하는 코드를 작성하시오(1점)

# %%
# 데이터 df를 year 컬럼의 값을 기준으로 정렬합니다.
# 기본 정렬 방식은 오름차순(ascending)입니다.
# 내림차순으로 정렬하고 싶다면 ascending 옵션을 False로 설정하면 됩니다.
world_corona_sorted_by_values = world_corona.sort_values(by='population' ,ascending=False)

# 정렬 결과를 출력합니다.
world_corona_sorted_by_values.head()
# Out:
#       iso_code continent  ... human_development_index is_valid
# 10565      CHN      Asia  ...                   0.752        1
# 10679      CHN      Asia  ...                   0.752        1
# 10686      CHN      Asia  ...                   0.752        1
# 10685      CHN      Asia  ...                   0.752        1
# 10684      CHN      Asia  ...                   0.752        1
#
# [5 rows x 49 columns]

# %% [markdown]
# 8. drop_duplicates 메서드를 활용하여, location별로 가장 마지막 날짜의 데이터만 남기는 코드를 작성하시오(2점)(코드 실행 결과 총 row의 개수는 213개가 되어야 함)

# %%
world_corona.duplicated('location', keep='last')
world_corona.drop_duplicates('location', keep='last',inplace=False)
# Out:
#       iso_code continent  ... human_development_index is_valid
# 309        AFG      Asia  ...                   0.498        1
# 550        ALB    Europe  ...                   0.785        1
# 860        DZA    Africa  ...                   0.754        1
# 1102       AND    Europe  ...                   0.858        1
# 1330       AGO    Africa  ...                   0.581        1
# ...        ...       ...  ...                     ...      ...
# 53124      WLF   Oceania  ...                     NaN        1
# 53317      ESH    Africa  ...                     NaN        1
# 53526      YEM      Asia  ...                   0.452        1
# 53757      ZMB    Africa  ...                   0.588        1
# 53986      ZWE    Africa  ...                   0.535        1
#
# [213 rows x 49 columns]

# %%
world_corona.shape
# Out:
# (53987, 49)

# %% [markdown]
# 9. world_corona 데이터를 지역('location')별로 그룹화하되, 그룹화 방식은 합계(sum)으로 진행하시오. 이 때, 해당 그룹화된 데이터에서 'new_cases'만을 출력하시오(2점)

# %%
# groupby는 pandas 데이터 분석의 꽃 -> 데이터 재구조화
# [데이터프레임명.groupby(칼럼명).구조화방식()] 처럼 사용한다
world_corona.groupby('location').sum()['new_cases']
# Out:
# location
# Afghanistan          41814.0
# Albania              21904.0
# Algeria              58979.0
# Andorra               4910.0
# Angola               11228.0
#                       ...
# Wallis and Futuna        1.0
# Western Sahara         766.0
# Yemen                 2067.0
# Zambia               16661.0
# Zimbabwe              8410.0
# Name: new_cases, Length: 213, dtype: float64

# %% [markdown]
# 10. world_corona에는 총 몇 개의 국가('location')가 있는가?(1점)

# %%
world_corona['location'].nunique()
# Out:
# 213

# %% [markdown]
# 11. world_corona에서, 2020년 10월 30일에 하루동안 발생한 전세계 확진자는 몇 명인가?(2점)

# %%
world_corona.groupby('date').sum()['total_cases']
# Out:
# date
# 2019-12-31          27.0
# 2020-01-01          27.0
# 2020-01-02          27.0
# 2020-01-03          44.0
# 2020-01-04          44.0
#                  ...
# 2020-10-31    45724683.0
# 2020-11-01    46181886.0
# 2020-11-02    46668710.0
# 2020-11-03    46676055.0
# 2020-11-04    45746425.0
# Name: total_cases, Length: 310, dtype: float64

# %%
world_corona.groupby('date').sum()['total_cases'][304]
# Out:
# 45183011.0

# %% [markdown]
# 12. world_corona에서 'Continent'가 'Europe'일 때, 총 몇 개의 location이 있는가?(unique한 location을 의미)(2점)

# %%
# df['continent'=='Europe']
# df[df['국어']>=70]
world_corona[world_corona['continent']=='Europe']['location'].unique()
# iris['class'].unique()
# Out:
# array(['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Estonia', 'Faeroe Islands',
#        'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Guernsey',
#        'Hungary', 'Iceland', 'Ireland', 'Isle of Man', 'Italy', 'Jersey',
#        'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Macedonia', 'Malta', 'Moldova', 'Monaco', 'Montenegro',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia',
#        'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Ukraine', 'United Kingdom', 'Vatican'],
#       dtype=object)

# %%
world_corona[world_corona['continent']=='Europe']['location'].nunique()
# Out:
# 51

# %% [markdown]
# 13. world_corona에서, 'Japan'의 총 확진자는 몇 명인가?(2점)

# %%
world_corona[world_corona['location']=='Japan']
# Out:
#       iso_code continent  ... human_development_index is_valid
# 25479      JPN      Asia  ...                   0.909        1
# 25480      JPN      Asia  ...                   0.909        1
# 25481      JPN      Asia  ...                   0.909        1
# 25482      JPN      Asia  ...                   0.909        1
# 25483      JPN      Asia  ...                   0.909        1
# ...        ...       ...  ...                     ...      ...
# 25784      JPN      Asia  ...                   0.909        1
# 25785      JPN      Asia  ...                   0.909        1
# 25786      JPN      Asia  ...                   0.909        1
# 25787      JPN      Asia  ...                   0.909        1
# 25788      JPN      Asia  ...                   0.909        1
#
# [310 rows x 49 columns]

# %% [markdown]
# 102900.0

# %%
# object 타입을 datetime64[ns] 타입으로 바꾼다 
world_corona['date'] = pd.to_datetime(world_corona['date'], format='%Y-%m-%d', errors='raise')

# %%
world_corona['date_month'] = world_corona['date'].dt.month        
# 월(숫자)

# %%
df_month = world_corona[world_corona['location']=='France']
df_month[df_month['date_month']==7]
# Out:
#       iso_code continent  ... is_valid date_month
# 17661      FRA    Europe  ...        1          7
# 17662      FRA    Europe  ...        1          7
# 17663      FRA    Europe  ...        1          7
# 17664      FRA    Europe  ...        1          7
# 17665      FRA    Europe  ...        1          7
# 17666      FRA    Europe  ...        1          7
# 17667      FRA    Europe  ...        1          7
# 17668      FRA    Europe  ...        1          7
# 17669      FRA    Europe  ...        1          7
# 17670      FRA    Europe  ...        1          7
# 17671      FRA    Europe  ...        1          7
# 17672      FRA    Europe  ...        1          7
# 17673      FRA    Europe  ...        1          7
# 17674      FRA    Europe  ...        1          7
# 17675      FRA    Europe  ...        1          7
# 17676      FRA    Europe  ...        1          7
# 17677      FRA    Europe  ...        1          7
# 17678      FRA    Europe  ...        1          7
# ...

# %%
# iris.groupby('class').sum()
df_month[df_month['date_month']==7].groupby('date_month').sum()
# Out:
#             total_cases  new_cases  ...  human_development_index  is_valid
# date_month                          ...
# 7             5394726.0    22313.0  ...                   27.931        31
#
# [1 rows x 44 columns]

# %% [markdown]
# 22313.0

# %%
# world_corona[world_corona['iso_code']=='KOR']
df_month_kor = world_corona[world_corona['iso_code']=='KOR']
# df_month_kor
# df_month[df_month['date_month']==7]
df_month_kor[df_month_kor['date_month']==7].groupby('date_month').sum()
# Out:
#             total_cases  new_cases  ...  human_development_index  is_valid
# date_month                          ...
# 7              421889.0     1505.0  ...                   27.993        31
#
# [1 rows x 44 columns]

# %%
22313.0/1505.0
# Out:
# 14.825913621262458

# %% [markdown]
# 15. world_corona에서, 1인당 gdp('gdp_per_capita')가 가장 높은 location은 어디인가?(1점)

# %%
world_corona[world_corona['gdp_per_capita']>110000]['location']
# Out:
# 39934    Qatar
# 39935    Qatar
# 39936    Qatar
# 39937    Qatar
# 39938    Qatar
#          ...
# 40239    Qatar
# 40240    Qatar
# 40241    Qatar
# 40242    Qatar
# 40243    Qatar
# Name: location, Length: 310, dtype: object

# %% [markdown]
# Qatar

# %% [markdown]
# 16. seoul_df에서, 가장 많은 확진 요인('접촉력')을 차지하는 것은 무엇인가?(1점)

# %%
seoul_df.head()
# Out:
#      연번  확진달  확진일   환자번호  ...        시군구명_영문  ESRI_PK         위도          경도
# 0  5748   10   21  25530  ...      Dobong-gu      0.0  37.665861  127.031767
# 1  5747   10   21  25528  ...   Eunpyeong-gu      1.0  37.617612  126.922700
# 2  5746   10   21  25525  ...  Dongdaemun-gu      2.0  37.583801  127.050700
# 3  5745   10   21  25517  ...     Dongjak-gu      3.0  37.496504  126.944307
# 4  5744   10   21  25504  ...   Geumcheon-gu      4.0  37.460097  126.900155
#
# [5 rows x 22 columns]

# %%
seoul_df['접촉력'].value_counts().head(20)
# Out:
# 기타 확진자 접촉        818
# 성북구 사랑제일교회 관련    641
# 확인 중             586
# 해외 접촉 추정         415
# 감염경로 조사중         373
# 타시도 확진자 접촉       244
# 이태원 클럽 관련        139
# 8.15서울도심집회       126
# 리치웨이 관련          119
# 도봉구 다나병원          68
# 구로구 콜센터 관련        60
# 노원구 빛가온교회 관련      46
# 성북구 체대입시 관련       43
# 양천구 운동시설 관련       43
# 요양시설 관련           43
# 확인중               42
# 구로구 교회 관련         41
# 용인시 우리제일교회 관련     41
# 강남구 K보건산업         37
# 서대문구 세브란스병원       37
# Name: 접촉력, dtype: int64

# %% [markdown]
# 기타 확진자 접촉

# %% [markdown]
# 17. seoul_df에서, 가장 많은 확진자가 발생한 '지역'은 전체 서울 확진자의 몇 %를 차지하는가?(3점) (정답은 '1.23%'와 같은 포맷으로 입력)

# %%
seoul_df['지역'].value_counts().head(20)
# Out:
# 관악구     452
# 송파구     361
# 성북구     344
# 타시도     331
# 노원구     323
# 강남구     296
# 강서구     295
# 은평구     259
# 동작구     254
# 도봉구     223
# 서초구     210
# 중랑구     202
# 영등포구    200
# 강동구     199
# 구로구     193
# 양천구     186
# 마포구     180
# 동대문구    172
# 강북구     156
# 용산구     140
# Name: 지역, dtype: int64

# %%
seoul_df['지역'].value_counts().sum()
# Out:
# 5748

# %%
452/5748*100
# Out:
# 7.8636047320807245

# %% [markdown]
# 18. seoul_df에서, 가장 많은 월간 확진자가 발생한 때는 몇월인가?(2점)

# %%
seoul_df['확진달'].value_counts()
# Out:
# 8     2416
# 9     1304
# 6      460
# 10     425
# 3      391
# 7      281
# 5      228
# 4      156
# 2       80
# 1        7
# Name: 확진달, dtype: int64

# %% [markdown]
# 8월

# %% [markdown]
# 19. world_corona에서, 총 사망자가 두 번째로 적은 continent는 어디인가?(2점) (힌트:groupby 메서드 사용) new_death

# %%
world_corona.groupby('continent').sum()
# Out:
#                 total_cases   new_cases  ...  is_valid  date_month
# continent                                ...
# Africa         1.634788e+08   1814642.0  ...     12922       87294
# Asia           1.061534e+09  13995194.0  ...     12923       77755
# Europe         7.027802e+08  10659682.0  ...     14174       85624
# North America  1.060479e+09  11310109.0  ...      8648       57642
# Oceania        4.221411e+06     43454.0  ...      2085       13512
# South America  8.445009e+08   9766254.0  ...      3235       21106
#
# [6 rows x 45 columns]

# %% [markdown]
# Africa

# %% [markdown]
# 20. world_corona에서, 전세계에서 그간 발생한 총 사망자는 몇 명인가?(1점)

# %%
world_corona[world_corona['date']=='2020-11-04']
# Out:
#       iso_code continent  ... is_valid date_month
# 309        AFG      Asia  ...        1         11
# 550        ALB    Europe  ...        1         11
# 860        DZA    Africa  ...        1         11
# 1102       AND    Europe  ...        1         11
# 1330       AGO    Africa  ...        1         11
# ...        ...       ...  ...      ...        ...
# 53124      WLF   Oceania  ...        1         11
# 53317      ESH    Africa  ...        1         11
# 53526      YEM      Asia  ...        1         11
# 53757      ZMB    Africa  ...        1         11
# 53986      ZWE    Africa  ...        1         11
#
# [209 rows x 50 columns]

# %%
world_corona[world_corona['date']=='2020-11-04']['total_deaths'].sum()
# Out:
# 1161295.0

# %% [markdown]
# 21. world_corona에서, location이 'French Polynesia'인 지역의 iso_code는 무엇인가?(1점)

# %%
world_corona[world_corona['location']=='French Polynesia']['iso_code']
# Out:
# 17788    PYF
# 17789    PYF
# 17790    PYF
# 17791    PYF
# 17792    PYF
#         ...
# 18014    PYF
# 18015    PYF
# 18016    PYF
# 18017    PYF
# 18018    PYF
# Name: iso_code, Length: 231, dtype: object

# %% [markdown]
# PYF

# %% [markdown]
# 22.world_corona에서, 총 확진자('total_cases')와 총 사망자('total_deaths')간의 상관관계는 어떻게 되는가?(1점)(소숫점 이하 둘째자리까지 출력)

# %%
world_corona.corr()
# Out:
#                                     total_cases  ...  date_month
# total_cases                            1.000000  ...    0.136046
# new_cases                              0.839346  ...    0.111621
# new_cases_smoothed                     0.864978  ...    0.112603
# total_deaths                           0.911722  ...    0.116403
# new_deaths                             0.586770  ...    0.043866
# new_deaths_smoothed                    0.649872  ...    0.047242
# total_cases_per_million                0.260298  ...    0.386249
# new_cases_per_million                  0.098085  ...    0.189594
# new_cases_smoothed_per_million         0.137113  ...    0.253550
# total_deaths_per_million               0.277361  ...    0.234986
# new_deaths_per_million                 0.084368  ...    0.049097
# new_deaths_smoothed_per_million        0.134450  ...    0.070969
# icu_patients                           0.327124  ...   -0.157187
# ...

# %% [markdown]
# 0.91

# %% [markdown]
# 23. world_corona에서, location이 'Germany'인 데이터 중 확진자가 가장 많이 발생한 월의 확진자는 직전 월의 확진자 수의 몇배인가?(3점)(소숫점 첫째 자리까지, "3.4배"와 같은 형태로 작성)

# %%
world_corona[world_corona['location']=='Germany'].groupby('date_month').sum()
# Out:
#             total_cases  new_cases  ...  human_development_index  is_valid
# date_month                          ...
# 1                  14.0        5.0  ...                   29.016        31
# 2                 473.0       52.0  ...                   27.144        29
# 3              481584.0    61856.0  ...                   29.016        31
# 4             3737253.0    97206.0  ...                   28.080        30
# 5             5348664.0    22363.0  ...                   29.016        31
# 6             5624689.0    12777.0  ...                   28.080        30
# 7             6224385.0    14439.0  ...                   29.016        31
# 8             6958941.0    33683.0  ...                   29.016        31
# 9             7938368.0    46838.0  ...                   28.080        30
# 10           11370428.0   229534.0  ...                   29.016        31
# 11            2215929.0    58840.0  ...                    3.744         4
# ...

# %%
229534.0/46838.0
# Out:
# 4.900593535163756

# %% [markdown]
# 4.9배

# %% [markdown]
# 24. world_corona에서, continent가 'Europe'인 곳들 중 확진자 수가 두 번째로 많은 지역(location)은 어디인가?(3점)

# %%
# world_corona[world_corona['continent']=='Europe'].groupby('location').sum()
# world_corona[(world_corona['continent']=='Europe')&(world_corona['date']=='2020-11-04')]
temp = world_corona[(world_corona['continent']=='Europe')&(world_corona['date']=='2020-11-04')]
temp
# Out:
#        iso_code continent  ... is_valid date_month
# 550         ALB    Europe  ...        1         11
# 1102        AND    Europe  ...        1         11
# 3190        AUT    Europe  ...        1         11
# 4831        BLR    Europe  ...        1         11
# 6761        BIH    Europe  ...        1         11
# 7991        BGR    Europe  ...        1         11
# 12235       HRV    Europe  ...        1         11
# 12942       CYP    Europe  ...        1         11
# 13252       CZE    Europe  ...        1         11
# 13799       DNK    Europe  ...        1         11
# 16191       EST    Europe  ...        1         11
# 16672       FRO    Europe  ...        1         11
# 17477       FIN    Europe  ...        1         11
# 17787       FRA    Europe  ...        1         11
# 19106       DEU    Europe  ...        1         11
# 19572       GIB    Europe  ...        1         11
# 19882       GRC    Europe  ...        1         11
# ...

# %%
# temp['location'].value_counts()
# 내림차순으로 정렬하고 싶다면 ascending 옵션을 False로 설정하면 됩니다.
temp_sorted_by_values = temp.sort_values(by='total_cases' ,ascending=False)

# 정렬 결과를 출력합니다.
temp_sorted_by_values.head(20)
# Out:
#       iso_code continent  ... is_valid date_month
# 40863      RUS    Europe  ...        1         11
# 17787      FRA    Europe  ...        1         11
# 51317      GBR    Europe  ...        1         11
# 25241      ITA    Europe  ...        1         11
# 19106      DEU    Europe  ...        1         11
# 39458      POL    Europe  ...        1         11
# 50697      UKR    Europe  ...        1         11
# 35239      NLD    Europe  ...        1         11
# 13252      CZE    Europe  ...        1         11
# 40553      ROU    Europe  ...        1         11
# 47546      CHE    Europe  ...        1         11
# 39711      PRT    Europe  ...        1         11
# 3190       AUT    Europe  ...        1         11
# 4831       BLR    Europe  ...        1         11
# 22532      HUN    Europe  ...        1         11
# 32650      MDA    Europe  ...        1         11
# 44310      SVK    Europe  ...        1         11
# 24392      IRL    Europe  ...        1         11
# ...

# %% [markdown]
# France

# %% [markdown]
# 25. world_corona에서, 확진자 대비 사망자 비율이 가장 높은 지역의 비율은 얼마인가?(3점)(소숫점 첫 번째 자리까지, 입력 예시 33.5%)

# %%
world_corona.tail()
# Out:
#       iso_code continent  ... is_valid date_month
# 53982      ZWE    Africa  ...        1         10
# 53983      ZWE    Africa  ...        1         11
# 53984      ZWE    Africa  ...        1         11
# 53985      ZWE    Africa  ...        1         11
# 53986      ZWE    Africa  ...        1         11
#
# [5 rows x 50 columns]

# %%
world_corona['total_cases_total_deaths']= world_corona['total_deaths']/world_corona['total_cases']*100

# %%
temp = world_corona[world_corona['date']=='2020-11-04']
temp
# Out:
#       iso_code continent  ... date_month total_cases_total_deaths
# 309        AFG      Asia  ...         11                 3.702109
# 550        ALB    Europe  ...         11                 2.428780
# 860        DZA    Africa  ...         11                 3.372387
# 1102       AND    Europe  ...         11                 1.527495
# 1330       AGO    Africa  ...         11                 2.573922
# ...        ...       ...  ...        ...                      ...
# 53124      WLF   Oceania  ...         11                      NaN
# 53317      ESH    Africa  ...         11                 0.130548
# 53526      YEM      Asia  ...         11                29.124335
# 53757      ZMB    Africa  ...         11                 2.094712
# 53986      ZWE    Africa  ...         11                 2.925089
#
# [209 rows x 51 columns]

# %%
# 내림차순으로 정렬하고 싶다면 ascending 옵션을 False로 설정하면 됩니다.
temp_sorted_by_values = temp.sort_values(by='total_cases_total_deaths' ,ascending=False)

# 정렬 결과를 출력합니다.
temp_sorted_by_values.head()
# Out:
#       iso_code      continent  ... date_month total_cases_total_deaths
# 53526      YEM           Asia  ...         11                29.124335
# 32410      MEX  North America  ...         11                 9.867062
# 33657      MSR  North America  ...         11                 7.692308
# 14877      ECU  South America  ...         11                 7.464582
# 24621      IMN         Europe  ...         11                 6.741573
#
# [5 rows x 51 columns]

# %% [markdown]
# 29.1%

# %% [markdown]
# 26. world_corona에서, 행 번호가 1114인 데이터의 'total_deaths'의 값은 무엇인가?(1점)

# %%
world_corona.head()
# Out:
#   iso_code continent  ... date_month total_cases_total_deaths
# 0      AFG      Asia  ...         12                      NaN
# 1      AFG      Asia  ...          1                      NaN
# 2      AFG      Asia  ...          1                      NaN
# 3      AFG      Asia  ...          1                      NaN
# 4      AFG      Asia  ...          1                      NaN
#
# [5 rows x 51 columns]

# %%
world_corona.loc[1114, 'total_deaths']
# Out:
# 2.0

# %% [markdown]
# 27. world_corona에서, 확진자가 가장 많이 발생한 상위 10개 지역('loaction')의 확진자를 막대 그래프로 시각화하시오(3점)
# - 힌트1: groupby를 사용
# - 힌트2: sort_values()를 사용
# - 힌트3: 슬라이싱([:n] 또는 .head()를 사용하여 상위 n개를 출력

# %%
temp = world_corona[world_corona['date']=='2020-11-04'].groupby('location').sum()
temp
# Out:
#                    total_cases  new_cases  ...  date_month  total_cases_total_deaths
# location                                   ...
# Afghanistan            41814.0       86.0  ...          11                  3.702109
# Albania                21904.0      381.0  ...          11                  2.428780
# Algeria                58979.0      405.0  ...          11                  3.372387
# Andorra                 4910.0       22.0  ...          11                  1.527495
# Angola                 11228.0      193.0  ...          11                  2.573922
# ...                        ...        ...  ...         ...                       ...
# Wallis and Futuna          1.0        0.0  ...          11                  0.000000
# Western Sahara           766.0        0.0  ...          11                  0.130548
# Yemen                   2067.0        4.0  ...          11                 29.124335
# ...

# %%
# 내림차순으로 정렬하고 싶다면 ascending 옵션을 False로 설정하면 됩니다.
temp_sorted_by_values = temp.sort_values(by='total_cases' ,ascending=False)

# 정렬 결과를 출력합니다.
temp_sorted_by_values[:10]
# Out:
#                 total_cases  new_cases  ...  date_month  total_cases_total_deaths
# location                                ...
# United States     9383979.0    92734.0  ...          11                  2.478980
# India             8313876.0    46253.0  ...          11                  1.486804
# Brazil            5566049.0    11843.0  ...          11                  2.883482
# Russia            1673686.0    18648.0  ...          11                  1.722426
# France            1502763.0    36330.0  ...          11                  2.547907
# Argentina         1195263.0    12145.0  ...          11                  2.681586
# Colombia          1099392.0     6136.0  ...          11                  2.896783
# United Kingdom    1073882.0    20018.0  ...          11                  4.399925
# Mexico             938405.0     5250.0  ...          11                  9.867062
# Peru               908902.0     2357.0  ...          11                  3.809322
#
# [10 rows x 46 columns]

# %%
temp_sorted_by_values[:10]['total_cases'].plot(kind='bar')

# %% [markdown]
# 28. world_corona에서, 한국('South Korea')의 일별 확진자 추이를 선 그래프로 출력하시오(1점)

# %%
world_corona[world_corona['iso_code']=='KOR']
# Out:
#       iso_code continent  ... date_month total_cases_total_deaths
# 45085      KOR      Asia  ...         12                      NaN
# 45086      KOR      Asia  ...          1                      NaN
# 45087      KOR      Asia  ...          1                      NaN
# 45088      KOR      Asia  ...          1                      NaN
# 45089      KOR      Asia  ...          1                      NaN
# ...        ...       ...  ...        ...                      ...
# 45390      KOR      Asia  ...         10                 1.750217
# 45391      KOR      Asia  ...         11                 1.749578
# 45392      KOR      Asia  ...         11                 1.750711
# 45393      KOR      Asia  ...         11                 1.760734
# 45394      KOR      Asia  ...         11                 1.760446
#
# [310 rows x 51 columns]

# %%
temp = world_corona[world_corona['iso_code']=='KOR']

# %%
plt.plot(temp['date'], temp['new_cases'], marker='o', color='b')



plt.title('New_cases of South Korea', fontsize=20) 

plt.ylabel('new_cases', fontsize=14)

plt.xlabel('Date', fontsize=14)

plt.legend(fontsize=12, loc='best')

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# 29. world_corona에서, 전세계 월별 확진자 추이를 선 그래프로 출력하시오(2점)(단, 11월과 12월 데이터는 제외하시오)
# - 힌트: world_corona['month'] = pd.to_datetime(world_corona['date']).dt.month를 사용하면 특정 월 칼럼을 추가할 수 있다.

# %%
world_corona.head()
# Out:
#   iso_code continent  ... date_month total_cases_total_deaths
# 0      AFG      Asia  ...         12                      NaN
# 1      AFG      Asia  ...          1                      NaN
# 2      AFG      Asia  ...          1                      NaN
# 3      AFG      Asia  ...          1                      NaN
# 4      AFG      Asia  ...          1                      NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# 30. world_corona에서, 일본('Japan')의 일별 확진자와 누적 확진자 추이를 선 그래프로 동시에 표현하시오(2점)
# - 힌트: plt.plot을 한 셀에 같이 사용하면 그래프를 겹쳐 그릴 수 있다.
